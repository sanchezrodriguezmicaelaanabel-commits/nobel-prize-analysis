# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# - Tools and Librery used:
# * Python
# * Pandas
# * Seaborn
# * Matplotlib
# * Numpy

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

nobel= pd.read_csv("data/nobel.csv")
top_gender= nobel["sex"].value_counts().index[0]
top_country= nobel["birth_country"].value_counts().index[0]

nobel["usa_born"]= nobel["birth_country"] == "United States of America"
nobel["decade"]= (nobel["year"]//10)*10
ratio= nobel.groupby("decade")["usa_born"].mean()
ratio_decade= ratio.sort_values(ascending=False)
max_decade_usa= ratio_decade.index[0]
g= sns.relplot(x="decade", y="usa_born", data=nobel, kind="line")
g.fig.suptitle("Ratio Nobel Prize Winners", y=1.03)
plt.show()

nobel["Female_Winners"]= nobel["sex"] == "Female"
nobel["decade"]= (nobel["year"]//10)*10
Female_Ratio= nobel.groupby(["decade", "category"])["Female_Winners"].mean()
Ratio_sorted= Female_Ratio.sort_values(ascending=False)
Female_decade= Ratio_sorted.index[0]
max_female_dict={2020:"Literature"}
g= sns.relplot(x="decade", y="Female_Winners", data=nobel, kind="line", col="category")
g.fig.suptitle("Female Laureates")
plt.show()

Woman_win= nobel[nobel["sex"] == "Female"]
woman_order= Woman_win.sort_values("year")
first_woman_name= woman_order["full_name"].iloc[0]
first_woman_category= woman_order["category"].iloc[0]

Winners= nobel["full_name"].value_counts()
Most_win= Winners[Winners >= 2]
repeat_list= list(Most_win.index)
print(repeat_list)
# Out:
# ['Comité international de la Croix Rouge (International Committee of the Red Cross)', 'Linus Carl Pauling', 'John Bardeen', 'Frederick Sanger', 'Marie Curie, née Sklodowska', 'Office of the United Nations High Commissioner for Refugees (UNHCR)']

# %% [markdown]
# - Summary of the Exploratory Data Analysis (EDA) -
#
# This proyect allowed me to perform an demographic, trends and gender observation about Nobel Prize Academy and their winners since its creation in 1901 to 2023 using tools like pandas, seaborn and numpy.
# What I discovered the following facts:
#
# * Graphic and historical hegemony
#   The exploratory Analysis show us that men of USA and the country itself were the most common winners of Novel Prizes, their increase started post-World War II and reach their highest ratio of USA-born Winners on the 2000s.
#
# * Gender Gap evolution
#   The Analysis reveal a slow but steady rise in the presence and inclusion of women in the academy, being 2020 the years with the highest proportions of womans laurates. As I could see, literature category had the most presence of Female Laureates throughout year.
#
# * Prominent Female Figures
#   By filtering the data, I noticed several notables female figures, with Marie Curie being the first woman to receive a Novel Prize.
#
# * Exceptional cases
#   By filtering the data I could noticed that more than one recived two or more than two awards due to their dedication and innovations on their corresponding areas.
